# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels
from sklearn.model_selection import RepeatedKFold as rkf
from sklearn.feature_selection import RFECV as rfecv
from sklearn import linear_model as lm
import statsmodels.api as sm
from sklearn.preprocessing import OneHotEncoder
#from yellowbrick.regressor import ResidualsPlot as rp

# %%
data = pd.read_csv(r'D:\SS\Analytics\Python\Python material\case-full\ready_data2.csv')
# data_test = pd.read_csv(r'D:\SS\Analytics\Python\Python material\case-full\test_data.csv')
data.shape
# Out:
# (1460, 127)

# %%
x_train = data.drop(columns='SalePrice')
y_train = data.SalePrice

# x_test = data_test

# %%
reg = lm.LinearRegression()

op = rfecv(reg,cv=rkf(n_splits=10, n_repeats=5, random_state=42))

fit1 = op.fit(x_train,y_train)
print("R square:",fit1.score(x_train,y_train))

coln_index = fit1.get_support(indices=True)
print("Number of columns selected is",len(coln_index))

df = pd.DataFrame()
for i in coln_index:
    df = pd.concat([df,(x_train.iloc[:,i])],axis=1)
colns = list(df.columns)

y_pred = fit1.predict(x_train)
# RFECV_coef = fit1.estimator_.coef_
# RFECV_intercept = fit1.estimator_.intercept_
# RFECV_intercept
# Out:
# R square: 0.8560489192623475
# Number of columns selected is 117

# %%
x1_train = data[colns]
y1_train = data['SalePrice']
x1_train = sm.add_constant(x1_train)
sum_op = sm.OLS(y1_train,x1_train).fit()
print(sum_op.summary())

y1_pred = sum_op.predict(x1_train)
# y1_pred = sum_op.predict(x_test[colns])
# y1_pred
# SM_coef = sum_op.params
# SM_coef
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     71.52
# Date:                Thu, 21 May 2020   Prob (F-statistic):               0.00
# Time:                        15:36:30   Log-Likelihood:                -17129.
# No. Observations:                1460   AIC:                         3.448e+04
# Df Residuals:                    1347   BIC:                         3.508e+04
# Df Model:                         112
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -1.663e+05    1.7e+05     -0.977      0.329      -5e+05    1.68e+05
# OverallQual            1.114e+04   1228.820      9.068      0.000    8732.898    1.36e+04
# YearRemodAdd            181.4342     64.866      2.797      0.005      54.185     308.683
# 2ndFlrSF                 29.3661      4.606      6.375      0.000      20.330      38.402
# FullBath               6857.4222   2399.213      2.858      0.004    2150.822    1.16e+04
# TotRmsAbvGrd           6014.4758    862.102      6.977      0.000    4323.267    7705.685
# Fireplaces             1.934e+04   3199.774      6.043      0.000    1.31e+04    2.56e+04
# GarageYrBlt             -79.8595     63.759     -1.253      0.211    -204.937      45.218
# GarageCars             1.418e+04   2029.249      6.988      0.000    1.02e+04    1.82e+04
# LotFrontageImp          163.1917     44.439      3.672      0.000      76.014     250.370
# MSZoning_RH            1.261e+04   1.08e+04      1.169      0.242   -8546.143    3.38e+04
# MSZoning_RL            1.644e+04   7025.044      2.340      0.019    2660.510    3.02e+04
# MSZoning_RM            6221.7197   7463.487      0.834      0.405   -8419.602    2.09e+04
# Neighborhood_Blueste  -3442.4760   2.31e+04     -0.149      0.881   -4.87e+04    4.18e+04
# Neighborhood_BrDale   -6078.8652   9836.814     -0.618      0.537   -2.54e+04    1.32e+04
# Neighborhood_BrkSide   1796.6447   5901.683      0.304      0.761   -9780.845    1.34e+04
# Neighborhood_Edwards  -1.359e+04   4064.637     -3.344      0.001   -2.16e+04   -5616.422
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6268.468
# Skew:                           0.718   Prob(JB):                         0.00
# Kurtosis:                      13.049   Cond. No.                     3.56e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.21e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
plt.scatter(y1_pred,data.SalePrice,alpha = .5,c='k')
plt.xlabel("Pred Saleprice")
plt.ylabel("Actual Saleprice")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
residuals = sum_op.resid_pearson
plt.scatter(data.SalePrice,residuals,alpha = .5, c='k')
plt.grid(True,c='k',alpha = .3)
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

### OR ###
# vis = rp(op)
# vis.fit(x_train, y_train)
# vis.show()

# %%
plt.hist(residuals,bins=50,color='white',edgecolor='black')
plt.show()

# %%
influence = sum_op.get_influence()
(cd,p) = influence.cooks_distance
# cd
dof_resid = sum_op.df_resid
# dof
# Out:
# D:\SS\Anaconda\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in sqrt
#   return self.resid / sigma / np.sqrt(1 - hii)
# D:\SS\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# D:\SS\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# D:\SS\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)

# %%
df_cd = data.loc[cd<4/dof_resid,list(data.columns)].reset_index(drop=True)
df_cd.shape
# Out:
# D:\SS\Anaconda\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in less
#   """Entry point for launching an IPython kernel.
# (1367, 127)

# %%
x_train = df_cd.drop(columns='SalePrice')
y_train = df_cd.SalePrice

fit2 = op.fit(x_train,y_train)
print("R square:",fit2.score(x_train,y_train))

coln_index = fit2.get_support(indices=True)
print("Number of columns selected is",len(coln_index))

df = pd.DataFrame()
for i in coln_index:
    df = pd.concat([df,(x_train.iloc[:,i])],axis=1)
colns = list(df.columns)

y_pred = fit2.predict(x_train)
# Out:
# R square: 0.9255226648100083
# Number of columns selected is 112

# %%
x1_train = df_cd[colns]
y1_train = df_cd['SalePrice']
x1_train = sm.add_constant(x1_train)
sum_op1 = sm.OLS(y1_train,x1_train).fit()
print(sum_op1.summary())

y1_pred = sum_op1.predict(x1_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     160.8
# Date:                Thu, 21 May 2020   Prob (F-statistic):               0.00
# Time:                        15:37:19   Log-Likelihood:                -15384.
# No. Observations:                1367   AIC:                         3.097e+04
# Df Residuals:                    1268   BIC:                         3.148e+04
# Df Model:                          98
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  -5.63e+05   1.26e+05     -4.454      0.000   -8.11e+05   -3.15e+05
# OverallQual            8753.7521    812.248     10.777      0.000    7160.254    1.03e+04
# YearBuilt               131.5868     55.414      2.375      0.018      22.873     240.301
# YearRemodAdd            261.2869     42.116      6.204      0.000     178.662     343.912
# MasVnrArea               11.6532      3.921      2.972      0.003       3.960      19.346
# BsmtFinSF1               15.9228      1.809      8.803      0.000      12.374      19.471
# TotalBsmtSF              17.9970      3.739      4.813      0.000      10.662      25.332
# 1stFlrSF                 37.3503     13.333      2.801      0.005      11.193      63.508
# 2ndFlrSF                 50.4863     13.501      3.739      0.000      23.999      76.973
# GrLivArea                 5.0277     12.979      0.387      0.699     -20.435      30.490
# FullBath              -3705.3781   1622.748     -2.283      0.023   -6888.944    -521.812
# TotRmsAbvGrd           -743.8779    686.591     -1.083      0.279   -2090.857     603.101
-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
plt.scatter(y1_pred,df_cd.SalePrice,alpha = .5,c='k')
plt.xlabel("Pred Saleprice")
plt.ylabel("Actual Saleprice")
plt.show()

# %%
residuals1 = sum_op1.resid_pearson
plt.hist(residuals1,bins=50,color='white',edgecolor='black')
plt.show()

# %%
plt.scatter(df_cd.SalePrice,residuals1,alpha = .5, c='k')
plt.grid(True,c='k',alpha = .3)
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %%
plt.scatter(df_cd.YearBuilt,y1_pred,alpha = .5, c='k')
plt.xlabel("Yr Bulit")
plt.ylabel("Predicted SalePrice")
plt.show()

# %%
df_cd['g1985'] = np.where(df_cd['YearBuilt'] > 1985, '1', '0')
df_cd.g1985
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 1362    1
# 1363    0
# 1364    0
# 1365    0
# 1366    0
# Name: g1985, Length: 1367, dtype: object

# %%
enc = OneHotEncoder(drop='first',sparse=False)

addn_colns = pd.DataFrame(enc.fit_transform(df_cd[['g1985']]))
addn_colns.columns = enc.get_feature_names(['g1985'])
df_cd.drop('g1985', axis=1, inplace=True)
df_cd = pd.concat([df_cd, addn_colns], axis=1)
df_cd.drop('YearBuilt', axis=1, inplace=True)
# df_cd.to_csv(r'D:\SS\Analytics\Python\Python material\case-full\g1980.csv')

# %%
x_train = df_cd.drop(columns='SalePrice')
y_train = df_cd.SalePrice

fit3 = op.fit(x_train,y_train)
print("R square:",fit3.score(x_train,y_train))

coln_index = fit3.get_support(indices=True)
print("Number of columns selected is",len(coln_index))

df = pd.DataFrame()
for i in coln_index:
    df = pd.concat([df,(x_train.iloc[:,i])],axis=1)
colns = list(df.columns)

y_pred = fit3.predict(x_train)
# Out:
# R square: 0.9253741169148103
# Number of columns selected is 108

# %%
x2_train = df_cd[colns]
y2_train = df_cd.SalePrice

x2_train = sm.add_constant(x2_train)
sum_op2 = sm.OLS(y2_train,x2_train).fit()
print(sum_op2.summary())

y2_pred = sum_op2.predict(x2_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.925
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     160.4
# Date:                Thu, 21 May 2020   Prob (F-statistic):               0.00
# Time:                        15:39:12   Log-Likelihood:                -15385.
# No. Observations:                1367   AIC:                         3.097e+04
# Df Residuals:                    1268   BIC:                         3.148e+04
# Df Model:                          98
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -3.614e+05   1.16e+05     -3.112      0.002   -5.89e+05   -1.34e+05
# OverallQual            8791.9317    813.656     10.805      0.000    7195.671    1.04e+04
# YearRemodAdd            259.4745     42.213      6.147      0.000     176.660     342.289
# MasVnrArea               12.4487      3.916      3.179      0.002       4.766      20.132
# BsmtFinSF1               16.1081      1.812      8.889      0.000      12.553      19.663
# TotalBsmtSF              18.5039      3.729      4.962      0.000      11.188      25.820
# 1stFlrSF                 39.3649     13.311      2.957      0.003      13.250      65.479
# 2ndFlrSF                 52.3546     13.476      3.885      0.000      25.917      78.792
# GrLivArea                 1.4910     12.879      0.116      0.908     -23.776      26.759
# FullBath              -3509.5814   1619.803     -2.167      0.030   -6687.370    -331.793
# TotRmsAbvGrd           -632.6264    689.049     -0.918      0.359   -1984.429     719.176
# Fireplaces             9021.0457   2166.167      4.165      0.000    4771.381    1.33e+04
# GarageYrBlt             -71.2282     44.671     -1.594      0.111    -158.866      16.409
# GarageCars             3379.5638   1851.194      1.826      0.068    -252.176    7011.304
# Electrical_FuseF      -7762.2808   4929.367     -1.575      0.116   -1.74e+04    1908.332
# Electrical_FuseP       -1.24e+04    3.1e+04     -0.400      0.689   -7.32e+04    4.84e+04
# Electrical_SBrkr      -3455.7269   2412.968     -1.432      0.152   -8189.576    1278.123
# KitchenQual_Fa        -2.786e+04   5239.255     -5.317      0.000   -3.81e+04   -1.76e+04
# KitchenQual_Gd        -2.452e+04   2915.321     -8.410      0.000   -3.02e+04   -1.88e+04
# KitchenQual_TA        -2.704e+04   3275.365     -8.256      0.000   -3.35e+04   -2.06e+04
# Functional_Maj2       -2.366e+04   1.44e+04     -1.648      0.100   -5.18e+04    4510.937
# FireplaceQu_Gd         3986.1600   1700.469      2.344      0.019     650.118    7322.202
# FireplaceQu_Po         4392.6553   4931.467      0.891      0.373   -5282.078    1.41e+04
# FireplaceQu_tmp        7683.9632   2926.618      2.626      0.009    1942.417    1.34e+04
# GarageType_Attchd      1.604e+04   4738.252      3.385      0.001    6745.203    2.53e+04
# GarageType_BuiltIn     1.996e+04   5448.941      3.664      0.000    9273.653    3.07e+04
# GarageType_CarPort     2672.5924   9130.335      0.293      0.770   -1.52e+04    2.06e+04
# GarageType_Detchd      1.562e+04   4789.746      3.260      0.001    6219.476     2.5e+04
# GarageType_tmp         1960.9555   2748.064      0.714      0.476   -3430.296    7352.207
# GarageFinish_Unf       -585.3338   1656.528     -0.353      0.724   -3835.171    2664.504
# GarageFinish_tmp       1960.9555   2748.064      0.714      0.476   -3430.296    7352.207
# GarageQual_Fa         -1.303e+04   6695.498     -1.946      0.052   -2.62e+04     104.155
# GarageQual_Po         -7276.7205   2.32e+04     -0.314      0.753   -5.27e+04    3.82e+04
# GarageQual_TA         -1.064e+04   5708.970     -1.863      0.063   -2.18e+04     564.278
# GarageQual_tmp         1960.9555   2748.064      0.714      0.476   -3430.296    7352.207
# SaleType_ConLD        -5221.6460   8947.681     -0.584      0.560   -2.28e+04    1.23e+04
# SaleType_New           9494.1675   1823.854      5.206      0.000    5916.065    1.31e+04
# SaleType_Oth           5540.3699   1.19e+04      0.468      0.640   -1.77e+04    2.88e+04
# SaleType_WD            3497.4834   2844.127      1.230      0.219   -2082.229    9077.196
# SaleCondition_Partial  9494.1675   1823.854      5.206      0.000    5916.065    1.31e+04
# g1985_1                5732.2409   3253.884      1.762      0.078    -651.348    1.21e+04
# ==============================================================================
# Omnibus:                       73.417   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.974
# Skew:                           0.044   Prob(JB):                     3.92e-59
# Kurtosis:                       5.171   Cond. No.                     1.01e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.77e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
plt.scatter(y2_pred,df_cd.SalePrice,alpha = .5,c='k')
plt.xlabel("Pred Saleprice")
plt.ylabel("Actual Saleprice")
plt.show()

# %%
residuals2 = sum_op2.resid_pearson
plt.hist(residuals2,bins=50,color='white',edgecolor='black')
plt.show()

# %%
plt.scatter(df_cd.SalePrice,residuals2,alpha = .5, c='k')
plt.grid(True,c='k',alpha = .3)
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %%
influence1 = sum_op2.get_influence()
(cd1,p) = influence1.cooks_distance
# cd
dof_resid1 = sum_op2.df_resid
# dof
# Out:
# D:\SS\Anaconda\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in sqrt
#   return self.resid / sigma / np.sqrt(1 - hii)
# D:\SS\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# D:\SS\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# D:\SS\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)

# %%
df_yr = df_cd.loc[cd1<4/dof_resid1,list(df_cd.columns)].reset_index(drop=True)
df_yr.shape
# Out:
# D:\SS\Anaconda\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in less
#   """Entry point for launching an IPython kernel.
# (1285, 127)

# %%
x_train = df_yr.drop(columns='SalePrice')
y_train = df_yr.SalePrice

fit3 = op.fit(x_train,y_train)
print("R square:",fit3.score(x_train,y_train))

coln_index = fit3.get_support(indices=True)
print("Number of columns selected is",len(coln_index))

df = pd.DataFrame()
for i in coln_index:
    df = pd.concat([df,(x_train.iloc[:,i])],axis=1)
colns = list(df.columns)

y_pred = fit3.predict(x_train)
# Out:
# R square: 0.9435634257369824
# Number of columns selected is 119

# %%
x3_train = df_yr[colns]
y3_train = df_yr.SalePrice

x3_train = sm.add_constant(x3_train)
sum_op3 = sm.OLS(y3_train,x3_train).fit()
print(sum_op3.summary())

y3_pred = sum_op3.predict(x3_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     219.2
# Date:                Thu, 21 May 2020   Prob (F-statistic):               0.00
# Time:                        15:40:45   Log-Likelihood:                -14192.
# No. Observations:                1285   AIC:                         2.857e+04
# Df Residuals:                    1193   BIC:                         2.904e+04
# Df Model:                          91
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -3.067e+05   9.77e+04     -3.139      0.002   -4.98e+05   -1.15e+05
# OverallQual            8035.6442    686.568     11.704      0.000    6688.629    9382.659
# YearRemodAdd            231.1250     35.472      6.516      0.000     161.530     300.720
# MasVnrArea                9.0594      3.352      2.703      0.007       2.483      15.636
# BsmtFinSF1               17.7472      1.539     11.534      0.000      14.728      20.766
# TotalBsmtSF              20.9127      3.167      6.602      0.000      14.698      27.127
# 1stFlrSF                 27.3425     13.693      1.997      0.046       0.477      54.208
# 2ndFlrSF                 38.8680     13.717      2.834      0.005      11.957      65.779
# GrLivArea                14.0999     13.365      1.055      0.292     -12.122      40.322
# FullBath              -1838.2442   1390.670     -1.322      0.186   -4566.675     890.186
# TotRmsAbvGrd          -1410.5858    585.827     -2.408      0.016   -2559.952    -261.219
# Fireplaces             4952.2395   1864.838      2.656      0.008    1293.511    8610.968
# GarageYrBlt             -76.7882     38.075     -2.017      0.044    -151.489      -2.088
# GarageCars             1537.8620   1538.597      1.000      0.318   -1480.796    4556.520
# GarageArea               30.7356      5.413      5.678      0.000      20.116      41.355
# WoodDeckSF               16.0637      4.101      3.917      0.000       8.017      24.110
# OpenPorchSF              12.2131      8.100      1.508      0.132      -3.679      28.105
# LotFrontageImp          225.2533     27.590      8.164      0.000     171.123     279.383
# MSZoning_RH            2828.1477   6321.906      0.447      0.655   -9575.143    1.52e+04
# MSZoning_RL            1.576e+04   4065.582      3.877      0.000    7786.458    2.37e+04
# MSZoning_RM            3908.0348   4401.079      0.888      0.375   -4726.681    1.25e+04
# Neighborhood_Blueste   1.647e-10   2.26e-10      0.728      0.467   -2.79e-10    6.08e-10
# Neighborhood_BrDale    -795.4954   5180.660     -0.154      0.878    -1.1e+04    9368.723
# Neighborhood_BrkSide   5029.5492   3148.672      1.597      0.110   -1148.002    1.12e+04
# HeatingQC_Po           2.069e-12   1.33e-12      1.551      0.121   -5.48e-13    4.69e-12
# HeatingQC_TA          -3852.9849   1271.089     -3.031      0.002   -6346.804   -1359.166
# Electrical_FuseF      -8471.5858   4027.461     -2.103      0.036   -1.64e+04    -569.891
# Electrical_SBrkr      -3933.1605   2012.971     -1.954      0.051   -7882.518      16.197
# KitchenQual_Fa        -2.589e+04   4533.533     -5.710      0.000   -3.48e+04    -1.7e+04
# KitchenQual_Gd        -2.529e+04   2521.480    -10.032      0.000   -3.02e+04   -2.03e+04
# KitchenQual_TA        -2.595e+04   2814.160     -9.222      0.000   -3.15e+04   -2.04e+04
# Functional_Maj2       -2.604e+04   1.17e+04     -2.223      0.026    -4.9e+04   -3058.662
# Functional_Sev                 0          0        nan        nan           0           0
# FireplaceQu_Gd         4049.8263   1445.263      2.802      0.005    1214.286    6885.366
# FireplaceQu_Po         6695.9917   4139.314      1.618      0.106   -1425.155    1.48e+04
# FireplaceQu_tmp        3194.5686   2477.200      1.290      0.197   -1665.585    8054.722
# GarageType_Attchd      1.737e+04   4346.958      3.997      0.000    8846.426    2.59e+04
# GarageType_BuiltIn     2.163e+04   4906.682      4.407      0.000     1.2e+04    3.13e+04
# GarageType_CarPort     9236.6574   8116.196      1.138      0.255   -6686.950    2.52e+04
# GarageType_Detchd      1.852e+04   4432.053      4.179      0.000    9824.762    2.72e+04
# GarageType_tmp         5719.3380   2407.298      2.376      0.018     996.329    1.04e+04
# GarageFinish_Unf      -1722.6943   1370.761     -1.257      0.209   -4412.065     966.677
# GarageFinish_tmp       5719.3380   2407.298      2.376      0.018     996.329    1.04e+04
# GarageQual_Fa         -7620.0030   5786.977     -1.317      0.188    -1.9e+04    3733.782
# GarageQual_TA         -2729.8578   4926.996     -0.554      0.580   -1.24e+04    6936.684
# GarageQual_tmp         5719.3380   2407.298      2.376      0.018     996.329    1.04e+04
# SaleType_ConLD        -4332.6404   7329.415     -0.591      0.555   -1.87e+04       1e+04
# SaleType_New           8515.5691   1556.109      5.472      0.000    5462.553    1.16e+04
# SaleType_Oth          -2293.1464   1.66e+04     -0.138      0.890   -3.48e+04    3.02e+04
# SaleType_WD            5001.2238   2423.396      2.064      0.039     246.632    9755.816
# SaleCondition_AdjLand          0          0        nan        nan           0           0
# SaleCondition_Partial  8515.5691   1556.109      5.472      0.000    5462.553    1.16e+04
# g1985_1                4843.4158   2730.694      1.774      0.076    -514.081    1.02e+04
# ==============================================================================
# Omnibus:                        6.571   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                8.434
# Skew:                          -0.007   Prob(JB):                       0.0147
# Kurtosis:                       3.397   Cond. No.                     1.09e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.4e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# D:\SS\Anaconda\lib\site-packages\statsmodels\base\model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# D:\SS\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# D:\SS\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# D:\SS\Anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)

# %%
plt.scatter(y3_pred,df_yr.SalePrice,alpha = .5,c='k')
plt.xlabel("Pred Saleprice")
plt.ylabel("Actual Saleprice")
plt.show()

# %%
residuals3 = sum_op3.resid_pearson
plt.hist(residuals3,bins=50,color='white',edgecolor='black')
plt.show()

# %%
plt.scatter(df_cd.SalePrice,residuals2,alpha = .5, c='k')
plt.grid(True,c='k',alpha = .3)
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()
